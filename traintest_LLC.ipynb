# %%
import time
import pprint
import numpy as np
import DRL.takeoff_dqn as tfdqn
import LLC 
import scaffold.fgdata as dfer
import scaffold.pidpilot as PID
import datetime
import fgmodule.fgenv as fgenv
import pandas as pd
import os
from scaffold.timer import gettime
import gym

'''
##########controlframe############


##########state_dict##############
{'aileron': 0.0, 'elevator': 0.0, 'rudder': -0.026, 'flaps': 0.0, 'throttle0': 0.6, 'throttle1': 0.6, 'vsi-fpm': 0.0, 'alt-ft': -372.808502, 'ai-pitch': 0.401045, 'ai-roll': 0.050598, 'ai-offset': 0.0, 'hi-heading': 80.568947, 'roll-deg': 0.050616, 'pitch-deg': 0.401055, 'heading-deg': 90.013458, 'airspeed-kt': 71.631187, 'speed-north-fps': -0.021637, 'speed-east-fps': 119.609383, 'speed-down-fps': -0.071344, 'uBody-fps': 119.606964, 'vBody-fps': -0.005778, 'wBody-fps': 0.765776, 'north-accel-fps_sec': 0.118887, 'east-accel-fps_sec': 5.870498, 'down-accel-fps_sec': -0.003219, 'x-accel-fps_sec': 6.095403, 'y-accel-fps_sec': -0.148636, 'z-accel-fps_sec': -32.113453, 'latitude': 21.325245, 'longitude': -157.93947, 'altitude': 22.297876, 'crashed': 0.0}
'''

actions_list = [
    'a_aileron',  # 副翼 控制飞机翻滚 [-1,1]
    'a_elevator',  # 升降舵 控制飞机爬升 [-1,1]
    'a_rudder',  # 方向舵 控制飞机转弯（地面飞机方向控制） [-1,1]
    'a_throttle0',  # 油门0 [0,1]
    'a_throttle1'  # 油门1 [0,1]
    # 'flaps',  # 襟翼 在飞机起降过程中增加升力，阻力 [0,1],实测影响不大，而且有速度限制
    #TODO: 方向舵调整片
]
LLC_FEATURES = [
    'pitch-deg',  # 飞机俯仰角
    'roll-deg',  # 飞机滚转角
    'heading-deg',  # 飞机朝向
    'vsi-fpm',  # 爬升速度
    'uBody-fps',  # 飞机沿机身X轴的速度
    'vBody-fps',  # 飞机沿机身Y轴的速度
    'wBody-fps',  # 飞机沿机身Z轴的速度
    'x-accel-fps_sec',  # 飞机沿机身X轴的加速度
    'y-accel-fps_sec',  # 飞机沿机身Y轴的加速度
    'z-accel-fps_sec',  # 飞机沿机身z轴的加速度
]


LLC_GOALS = {
    'pitch-deg': 0.0,  # 飞机俯仰角
    'roll-deg': 0.0,  # 飞机滚转角
    'heading-deg': 90.0,  # 飞机朝向
    'vsi-fpm': 0.0,  # 爬升速度
    'uBody-fps': 120.0,  # 飞机沿机身X轴的速度
    'vBody-fps': 0.0,  # 飞机沿机身Y轴的速度
    'wBody-fps': 0.0,  # 飞机沿机身Z轴的速度
    'x-accel-fps_sec': 5.0,  # 飞机沿机身X轴的加速度
    'y-accel-fps_sec': 0.0,  # 飞机沿机身Y轴的加速度
    'z-accel-fps_sec': 0.0,  # 飞机沿机身z轴的加速度
}

LLC_FEATURE_BOUNDS = {
    'pitch-deg': [-90., 90.],  # 飞机俯仰角
    'roll-deg': [-180., 180.],  # 飞机滚转角
    'heading-deg': [0., 360.],  # 飞机朝向
    'vsi-fpm': [0., 10.0],  # 爬升速度
    'uBody-fps': [0., 600.],  # 飞机沿机身X轴的速度
    'vBody-fps': [-200., 200.],  # 飞机沿机身Y轴的速度
    'wBody-fps': [-200., 200.],  # 飞机沿机身Z轴的速度
    'x-accel-fps_sec': [0., 50.],  # 飞机沿机身X轴的加速度
    'y-accel-fps_sec': [-30., 30.],  # 飞机沿机身Y轴的加速度
    'z-accel-fps_sec': [-300., 300.],  # 飞机沿机身z轴的加速度
}

LLC_ACTIONS = [
    'aileron',  # 副翼 控制飞机翻滚 [-1,1]
    'elevator',  # 升降舵 控制飞机爬升 [-1,1]
    'rudder',  # 方向舵 控制飞机转弯（地面飞机方向控制） [-1,1]
    'throttle0',  # 油门0 [0,1]
    'throttle1'  # 油门1 [0,1]
    # 'flaps',  # 襟翼 在飞机起降过程中增加升力，阻力 [0,1],实测影响不大，而且有速度限制
    #TODO: 方向舵调整片
]
DATA_ACTIONS = [
    'a_aileron',  # 副翼 控制飞机翻滚 [-1,1]
    'a_elevator',  # 升降舵 控制飞机爬升 [-1,1]
    'a_rudder',  # 方向舵 控制飞机转弯（地面飞机方向控制） [-1,1]
    'a_throttle0',  # 油门0 [0,1]
    'a_throttle1'  # 油门1 [0,1]
]
LLC_ACTION_BOUNDS = {
    'aileron': [-1, 1],  # 副翼 控制飞机翻滚 [-1,1] left/right
    'elevator': [-1, 1],  # 升降舵 控制飞机爬升 [-1,1] up/down
    'rudder': [-1, 1],  # 方向舵 控制飞机转弯（地面飞机方向控制） 0 /enter
    'throttle0': [0, 1],  # 油门0
    'throttle1': [0, 1],  # 油门1
    # 'flaps': [0, 0]  # 襟翼 在飞机起降过程中增加升力，阻力  Key[ / ]	Extend / retract flaps
    #TODO: 方向舵调整片
}

DATA_BOUNDS = {
    'pitch-deg': [-90., 90.],  # 飞机俯仰角
    'roll-deg': [-180., 180.],  # 飞机滚转角
    'heading-deg': [0., 360.],  # 飞机朝向
    'vsi-fpm': [0., 10.0],  # 爬升速度
    'uBody-fps': [0., 600.],  # 飞机沿机身X轴的速度
    'vBody-fps': [-200., 200.],  # 飞机沿机身Y轴的速度
    'wBody-fps': [-200., 200.],  # 飞机沿机身Z轴的速度
    'x-accel-fps_sec': [0., 50.],  # 飞机沿机身X轴的加速度
    'y-accel-fps_sec': [-30., 30.],  # 飞机沿机身Y轴的加速度
    'z-accel-fps_sec': [-300., 300.],  # 飞机沿机身z轴的加速度
    'aileron': [-1, 1],  # 副翼 控制飞机翻滚 [-1,1] left/right
    'elevator': [-1, 1],  # 升降舵 控制飞机爬升 [-1,1] up/down
    'rudder': [-1, 1],  # 方向舵 控制飞机转弯（地面飞机方向控制） 0 /enter
    'throttle0': [0, 1],  # 油门0
    'throttle1': [0, 1],  # 油门1
    'flaps': [0, 1],  # 襟翼 在飞机起降过程中增加升力，阻力  Key[ / ]	Extend / retract flaps
    #TODO: 方向舵调整片
    'a_aileron': [-1, 1],  # 副翼 控制飞机翻滚 [-1,1] left/right
    'a_elevator': [-1, 1],  # 升降舵 控制飞机爬升 [-1,1] up/down
    'a_rudder': [-1, 1],  # 方向舵 控制飞机转弯（地面飞机方向控制） 0 /enter
    'a_throttle0': [0, 1],  # 油门0
    'a_throttle1': [0, 1],  # 油门1
}


def fgstart(fg2client_addr=("127.0.0.1", 5700), client2fg_addr=("127.0.0.1", 5701), telnet_addr=("127.0.0.1", 5555)):
    '''
    简化FG通信启动过程
    ---
    Inputs:
        - fg2client_addr
        - client2fg_addr
        - telnet_addr
    Outputs:
        - myfgenv:初始话完成的fgenv类

    '''
    myfgenv = fgenv.fgenv(telnet_addr, fg2client_addr, client2fg_addr)
    # initial_state = myfgenv.initial()
    myfgenv.initial()

    return myfgenv


MAX_EPISODE = 1000
MAX_EP_STEPS = 200

GAMMA = 0.9
LR_A = 0.001    # learning rate for actor
LR_C = 0.01     # learning rate for critic

##
epoch = 100
step = 300

# %%
target_states = dfer.load_target_state("data/traindata")

# %%
myfgenv = fgstart()

# bounds = {
#     'rudder': [-1, 1],  # 方向舵 控制飞机转弯（地面飞机方向控制） 0 /enter
# }
# Out:
# flylog saving path check pass!
# send data to 127.0.0.1:5701 !
# fgudp is ready!!!
# Bind UDP on 127.0.0.1:5700 !
# save log to data/flylog
# auto start完成 23 : 9 : 1
# fgudp stop begin! waiting for 2 thread quit
# send data to 127.0.0.1:5701 stop!UDP rece on 127.0.0.1:5700 stop!
#
# reset完成 23 : 9 : 2
# flylog saving path check pass!
# send data to 127.0.0.1:5701 !
# fgudp is ready!!!
# Bind UDP on 127.0.0.1:5700 !
# save log to data/flylog
# auto start完成 23 : 9 : 57

# %%
# myllc.sess.close()

# %%
myllc = LLC.LLC(LLC_FEATURE_BOUNDS,LLC_FEATURE_BOUNDS,LLC_ACTION_BOUNDS)

# %%
state = myfgenv.replay()
# Out:
# replay to ground 完成!time:23 : 10 : 14
# auto start完成 23 : 10 : 17

# %%
state
# Out:
# {'aileron': 0.0,
#  'elevator': 0.0,
#  'rudder': 0.0,
#  'flaps': 0.0,
#  'throttle0': 0.0,
#  'throttle1': 0.0,
#  'vsi-fpm': 0.0,
#  'alt-ft': -372.246063,
#  'ai-pitch': 0.503405,
#  'ai-roll': 0.179295,
#  'ai-offset': 0.0,
#  'hi-heading': 82.918945,
#  'roll-deg': 0.056098,
#  'pitch-deg': 0.466483,
#  'heading-deg': 90.002332,
#  'airspeed-kt': 1.532065,
#  'speed-north-fps': -0.000307,
#  'speed-east-fps': 0.048647,
#  'speed-down-fps': 0.00012,
#  'uBody-fps': 0.048645,
#  'vBody-fps': 0.000305,
#  'wBody-fps': 0.000516,
#  'north-accel-fps_sec': 7.4e-05,
#  'east-accel-fps_sec': -0.05512,
#  'down-accel-fps_sec': -0.000414,
#  'x-accel-fps_sec': 0.206657,
#  'y-accel-fps_sec': -0.031552,
#  'z-accel-fps_sec': -32.152016,
#  'latitude': 21.325247,
#  'longitude': -157.943136,
#  'altitude': 21.357961,
#  'crashed': 0.0}

# %%
goal = dfer.get_target_state(state, target_states)
goal
# Out:
# {'pitch-deg': 0.443287,
#  'roll-deg': 0.056379999999999986,
#  'heading-deg': 90.000221,
#  'vsi-fpm': 0.0,
#  'uBody-fps': 4.114077,
#  'vBody-fps': 0.000356,
#  'wBody-fps': 0.028794,
#  'x-accel-fps_sec': 2.742848,
#  'y-accel-fps_sec': -0.031711,
#  'z-accel-fps_sec': -32.134853}

# %%
myllc.goals
# Out:
# {'pitch-deg': [-90.0, 90.0],
#  'roll-deg': [-180.0, 180.0],
#  'heading-deg': [0.0, 360.0],
#  'vsi-fpm': [0.0, 10.0],
#  'uBody-fps': [0.0, 600.0],
#  'vBody-fps': [-200.0, 200.0],
#  'wBody-fps': [-200.0, 200.0],
#  'x-accel-fps_sec': [0.0, 50.0],
#  'y-accel-fps_sec': [-30.0, 30.0],
#  'z-accel-fps_sec': [-300.0, 300.0]}

# %%
myllc.choose_action(state,goal)
# Out:
# (array([-1.        , -0.09898096, -1.        ,  0.5       , -0.5       ]),
#  array([-1.        , -0.09898096, -1.        ,  1.        ,  0.        ]))

# %%
import importlib
importlib.reload(LLC)
# Out:
# <module 'LLC' from 'E:\\project\\flightgear\\FGAutopilot\\LLC.py'>

# %%
 for e in range(epoch):
        state = myfgenv.replay()
        time.sleep(2)

        goal_count = 0
        goal = dfer.get_target_state(state, target_states)
        next_goal = goal

        ep_reward = 0

        for s in range(step):

            goal_count +=1

            action,action_true = myllc.choose_action(state,goal)

            action_frame = dfer.action2frame(action_true)
            next_state, reward , done , info = myfgenv.step(action_frame) 
            
            r_ = LLC.llc_reward(state , goal, reward)

            if goal_count%5 ==0:
                next_goal = dfer.get_target_state(next_state, target_states)

            myllc.learn(state, goal, r_, action,next_state , next_goal)
            
            state = next_state
            goal = next_goal

            ep_reward += r_
            if done:
                print('Episode:', e, ' Reward: %i' %
                      int(ep_reward), 'Explore: %.2f' % myllc.var, )
                break
            
            if s == step-1:
                print('Episode:', e, ' Reward: %i' %
                      int(ep_reward), 'Explore: %.2f' % myllc.var, )
                # if ep_reward > -300:RENDER = True
                break
            time.sleep(0.1)
# Out:
# replay to ground 完成!time:23 : 15 : 30
# auto start完成 23 : 15 : 33
# Episode: 0  Reward: -1407 Explore: 3.00
# replay to ground 完成!time:23 : 16 : 10
# auto start完成 23 : 16 : 13
# Episode: 1  Reward: -1283 Explore: 3.00
# replay to ground 完成!time:23 : 16 : 50
# auto start完成 23 : 16 : 53
# Episode: 2  Reward: -1210 Explore: 3.00
# replay to ground 完成!time:23 : 17 : 30
# auto start完成 23 : 17 : 33
# Episode: 3  Reward: -1115 Explore: 3.00
# replay to ground 完成!time:23 : 18 : 10
# auto start完成 23 : 18 : 13
# Episode: 4  Reward: -1332 Explore: 3.00
# replay to ground 完成!time:23 : 18 : 50
# auto start完成 23 : 18 : 53
# Episode: 5  Reward: -991 Explore: 3.00
# replay to ground 完成!time:23 : 19 : 30
# auto start完成 23 : 19 : 33
# Episode: 6  Reward: -1108 Explore: 3.00
# replay to ground 完成!time:23 : 20 : 10
# auto start完成 23 : 20 : 13
# Episode: 7  Reward: -1249 Explore: 3.00
# replay to ground 完成!time:23 : 20 : 50
# auto start完成 23 : 20 : 53
# Episode: 8  Reward: -1288 Explore: 3.00
# replay to ground 完成!time:23 : 21 : 28
# auto start完成 23 : 21 : 31
# Episode: 9  Reward: -1126 Explore: 3.00
# replay to ground 完成!time:23 : 22 : 7
# auto start完成 23 : 22 : 10
# Episode: 10  Reward: -1028 Explore: 3.00
# replay to ground 完成!time:23 : 22 : 45
# auto start完成 23 : 22 : 48
# Episode: 11  Reward: -1267 Explore: 3.00
# replay to ground 完成!time:23 : 23 : 20
# auto start完成 23 : 23 : 23
# Episode: 12  Reward: -950 Explore: 3.00
# replay to ground 完成!time:23 : 23 : 56
# auto start完成 23 : 23 : 59
# Episode: 13  Reward: -1064 Explore: 3.00
# replay to ground 完成!time:23 : 24 : 32
# auto start完成 23 : 24 : 35
# Episode: 14  Reward: -1071 Explore: 3.00
# replay to ground 完成!time:23 : 25 : 8
# auto start完成 23 : 25 : 11
# Episode: 15  Reward: -1111 Explore: 3.00
# replay to ground 完成!time:23 : 25 : 48
# auto start完成 23 : 25 : 51
# Episode: 16  Reward: -1123 Explore: 3.00
# replay to ground 完成!time:23 : 26 : 28
# auto start完成 23 : 26 : 31
# Episode: 17  Reward: -1155 Explore: 3.00
# replay to ground 完成!time:23 : 27 : 8
# auto start完成 23 : 27 : 11
# Episode: 18  Reward: -1331 Explore: 3.00
# replay to ground 完成!time:23 : 27 : 48
# auto start完成 23 : 27 : 51
# Episode: 19  Reward: -644 Explore: 3.00
# replay to ground 完成!time:23 : 28 : 16
# auto start完成 23 : 28 : 19
# Episode: 20  Reward: -1379 Explore: 3.00
# replay to ground 完成!time:23 : 28 : 57
# auto start完成 23 : 29 : 0
# Episode: 21  Reward: -1102 Explore: 3.00
# replay to ground 完成!time:23 : 29 : 37
# auto start完成 23 : 29 : 40
# Episode: 22  Reward: -1544 Explore: 3.00
# replay to ground 完成!time:23 : 30 : 17
# auto start完成 23 : 30 : 20
# Episode: 23  Reward: -1220 Explore: 3.00
# replay to ground 完成!time:23 : 30 : 56
# auto start完成 23 : 30 : 59
# Episode: 24  Reward: -1221 Explore: 3.00
# replay to ground 完成!time:23 : 31 : 36
# auto start完成 23 : 31 : 39
# Episode: 25  Reward: -1087 Explore: 3.00
# replay to ground 完成!time:23 : 32 : 15
# auto start完成 23 : 32 : 18
# Episode: 26  Reward: -1086 Explore: 3.00
# replay to ground 完成!time:23 : 32 : 53
# auto start完成 23 : 32 : 56
# Episode: 27  Reward: -1238 Explore: 3.00
# replay to ground 完成!time:23 : 33 : 32
# auto start完成 23 : 33 : 35
# Episode: 28  Reward: -1326 Explore: 3.00
# replay to ground 完成!time:23 : 34 : 12
# auto start完成 23 : 34 : 15
# Episode: 29  Reward: -1182 Explore: 2.86
# replay to ground 完成!time:23 : 34 : 52
# auto start完成 23 : 34 : 55
# Episode: 30  Reward: -1013 Explore: 2.46
# replay to ground 完成!time:23 : 35 : 32
# auto start完成 23 : 35 : 35
# Episode: 31  Reward: -1966 Explore: 2.12
# replay to ground 完成!time:23 : 36 : 13
# auto start完成 23 : 36 : 16
# Episode: 32  Reward: -2138 Explore: 1.82
# replay to ground 完成!time:23 : 36 : 53
# auto start完成 23 : 36 : 56
# Episode: 33  Reward: -2420 Explore: 1.57
# replay to ground 完成!time:23 : 37 : 33
# auto start完成 23 : 37 : 36
# Episode: 34  Reward: -1340 Explore: 1.35
# replay to ground 完成!time:23 : 38 : 13
# auto start完成 23 : 38 : 16
# Episode: 35  Reward: -2480 Explore: 1.16
# replay to ground 完成!time:23 : 38 : 53
# auto start完成 23 : 38 : 56
# Episode: 36  Reward: -2068 Explore: 1.00
# replay to ground 完成!time:23 : 39 : 33
# auto start完成 23 : 39 : 36
# Episode: 37  Reward: -1904 Explore: 0.86
# replay to ground 完成!time:23 : 40 : 13
# auto start完成 23 : 40 : 16
# Episode: 38  Reward: -1855 Explore: 0.74
# replay to ground 完成!time:23 : 40 : 53
# auto start完成 23 : 40 : 56
# Episode: 39  Reward: -1731 Explore: 0.64
# replay to ground 完成!time:23 : 41 : 34
# auto start完成 23 : 41 : 37
# Episode: 40  Reward: -1836 Explore: 0.55
# replay to ground 完成!time:23 : 42 : 14
# auto start完成 23 : 42 : 17
# Episode: 41  Reward: -1677 Explore: 0.47
# replay to ground 完成!time:23 : 42 : 51
# auto start完成 23 : 42 : 54
# Episode: 42  Reward: -1736 Explore: 0.41
# replay to ground 完成!time:23 : 43 : 27
# auto start完成 23 : 43 : 30
# Episode: 43  Reward: -1882 Explore: 0.35
# replay to ground 完成!time:23 : 44 : 3
# auto start完成 23 : 44 : 6
# Episode: 44  Reward: -1851 Explore: 0.30
# replay to ground 完成!time:23 : 44 : 39
# auto start完成 23 : 44 : 42
# Episode: 45  Reward: -2057 Explore: 0.26
# replay to ground 完成!time:23 : 45 : 15
# auto start完成 23 : 45 : 18
# Episode: 46  Reward: -2006 Explore: 0.22
# replay to ground 完成!time:23 : 45 : 51
# auto start完成 23 : 45 : 54
# Episode: 47  Reward: -2301 Explore: 0.19
# replay to ground 完成!time:23 : 46 : 27
# auto start完成 23 : 46 : 30
# Episode: 48  Reward: -2355 Explore: 0.17
# replay to ground 完成!time:23 : 47 : 3
# auto start完成 23 : 47 : 6
# Episode: 49  Reward: -2262 Explore: 0.14
# replay to ground 完成!time:23 : 47 : 39
# auto start完成 23 : 47 : 42
# Episode: 50  Reward: -2272 Explore: 0.12
# replay to ground 完成!time:23 : 48 : 15
# auto start完成 23 : 48 : 18
# Episode: 51  Reward: -2085 Explore: 0.11
# replay to ground 完成!time:23 : 48 : 51
# auto start完成 23 : 48 : 54
# Episode: 52  Reward: -2303 Explore: 0.09
# replay to ground 完成!time:23 : 49 : 27
# auto start完成 23 : 49 : 30
# Episode: 53  Reward: -2260 Explore: 0.08
# replay to ground 完成!time:23 : 50 : 3
# auto start完成 23 : 50 : 6
# Episode: 54  Reward: -2282 Explore: 0.07
# replay to ground 完成!time:23 : 50 : 39
# auto start完成 23 : 50 : 42
# Episode: 55  Reward: -2338 Explore: 0.06
# replay to ground 完成!time:23 : 51 : 17
# auto start完成 23 : 51 : 20
# Episode: 56  Reward: -2459 Explore: 0.05
# replay to ground 完成!time:23 : 51 : 56
# auto start完成 23 : 51 : 59
# Episode: 57  Reward: -2188 Explore: 0.04
# replay to ground 完成!time:23 : 52 : 33
# auto start完成 23 : 52 : 36
# Episode: 58  Reward: -2342 Explore: 0.04
# replay to ground 完成!time:23 : 53 : 10
# auto start完成 23 : 53 : 13
# Episode: 59  Reward: -2397 Explore: 0.03
# replay to ground 完成!time:23 : 53 : 49
# auto start完成 23 : 53 : 52
# Episode: 60  Reward: -2229 Explore: 0.03
# replay to ground 完成!time:23 : 54 : 27
# auto start完成 23 : 54 : 30
# Episode: 61  Reward: -2282 Explore: 0.02
# replay to ground 完成!time:23 : 55 : 5
# auto start完成 23 : 55 : 8
# Episode: 62  Reward: -2310 Explore: 0.02
# replay to ground 完成!time:23 : 55 : 43
# auto start完成 23 : 55 : 46
# Episode: 63  Reward: -1535 Explore: 0.02
# replay to ground 完成!time:23 : 56 : 10
# auto start完成 23 : 56 : 13
# Episode: 64  Reward: -1107 Explore: 0.02
# replay to ground 完成!time:23 : 56 : 33
# auto start完成 23 : 56 : 36
# Episode: 65  Reward: -2860 Explore: 0.01
# replay to ground 完成!time:23 : 57 : 11
# auto start完成 23 : 57 : 14
# Episode: 66  Reward: -2634 Explore: 0.01
# replay to ground 完成!time:23 : 57 : 51
# auto start完成 23 : 57 : 54
# Episode: 67  Reward: -2679 Explore: 0.01
# replay to ground 完成!time:23 : 58 : 28
# auto start完成 23 : 58 : 31
# Episode: 68  Reward: -2678 Explore: 0.01
# replay to ground 完成!time:23 : 59 : 6
# auto start完成 23 : 59 : 9
# Episode: 69  Reward: -1876 Explore: 0.01
# replay to ground 完成!time:23 : 59 : 45
# auto start完成 23 : 59 : 48
# Episode: 70  Reward: -1685 Explore: 0.01
# replay to ground 完成!time:0 : 0 : 24
# auto start完成 0 : 0 : 27
# Episode: 71  Reward: -1711 Explore: 0.01
# replay to ground 完成!time:0 : 1 : 3
# auto start完成 0 : 1 : 6
# Episode: 72  Reward: -1679 Explore: 0.01
# replay to ground 完成!time:0 : 1 : 43
# auto start完成 0 : 1 : 46
# Episode: 73  Reward: -1806 Explore: 0.00
# replay to ground 完成!time:0 : 2 : 22
# auto start完成 0 : 2 : 25
# Episode: 74  Reward: -1190 Explore: 0.00
# replay to ground 完成!time:0 : 3 : 1
# auto start完成 0 : 3 : 4
# Episode: 75  Reward: -2174 Explore: 0.00
# replay to ground 完成!time:0 : 3 : 41
# auto start完成 0 : 3 : 44
# Episode: 76  Reward: -1986 Explore: 0.00
# replay to ground 完成!time:0 : 4 : 20
# auto start完成 0 : 4 : 23
# Episode: 77  Reward: -2075 Explore: 0.00
# replay to ground 完成!time:0 : 4 : 59
# auto start完成 0 : 5 : 2
# Episode: 78  Reward: -1971 Explore: 0.00
# replay to ground 完成!time:0 : 5 : 38
# auto start完成 0 : 5 : 41
# Episode: 79  Reward: -1960 Explore: 0.00
# replay to ground 完成!time:0 : 6 : 17
# auto start完成 0 : 6 : 20
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-13-2124f0bad357> in <module>
#      39                # if ep_reward > -300:RENDER = True
#      40                break
# ---> 41            time.sleep(0.1)
#
# KeyboardInterrupt:

# %%
myllc.ddpg.pointer
# Out:
# 25081

# %%
t1= time.clock()
myllc.learn(state, goal, r_, action,next_state , next_goal)
print(time.clock()-t1)
# Out:
# 0.0027973283603017762
